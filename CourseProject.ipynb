# %% [markdown]
# # Tesla Stock Price Prediction
#
# Author: Xiangyi Zhu

# %% [markdown]
# ## Introduction

# %% [markdown]
# The stock market is very volatila, but with a large amount of data, we are able to find some trend. In the project, I imported the data of the stock price of Tesla from 2011 to 2017. In the project, I aim to use linear regression and K_Neatest neighbor to predict the future stock price and see whether the methods work for the volatila market. Also, I aim to see whether we can use the prediction to make the correct decision on trading.

# %% [markdown]
# ## Section1: Read and Organize the Dataset

# %%
import pandas as pd

# %%
df=pd.read_csv("Tesla.csv").dropna()

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %% [markdown]
# Create new columns in the dataframe which will be used in the following section

# %%
# the column contain the difference between high price and open price
df["Diff_high"]=df["High"]-df["Open"]

# %%
# the column contain the difference between low price and open price
df["Diff_low"]=df["Open"]-df["Low"]

# %%
# if the stock is worthing trading, the value is 1, otherwise the value is 0
df["Trade"]=df["Close"]-df["Open"]

df["Worth"]=0
for n in df.index:
    if df.loc[n,"Trade"]>=0:
        df.loc[n,"Worth"]=1

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001
#
#    Diff_high  Diff_low     Trade  Worth
# 0   6.000000  1.459999  4.889999      1
# 1   4.629999  2.490002 -1.960001      0
# 2   0.920000  4.730000 -3.040001      0
# 3   0.100000  4.290001 -3.799999      0
# 4   0.000000  4.170000 -3.889999      0

# %% [markdown]
# In order to predict the stock price, we need to first analyze the original data. Close price is the last price at which a security traded during the regular trading day is the standard benchmark used by investors to track its performance over time. So, we will first use chart to see the change of close over time.

# %%
import altair as alt

# %%
type(df["Close"])
# Out:
# pandas.core.series.Series

# %%
interval = alt.selection_interval()

big = alt.Chart(df).mark_line().encode(
    x="Date",
    y="Close",
    tooltip=["Date","Close"]
).add_selection(
    interval
)

small = alt.Chart(df).mark_line().encode(
    x="Date",
    y="Close"
).transform_filter(
    interval
)

big|small
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Section2: Linear Regression

# %% [markdown]
# I plan to use the data in 2013 and 2014 to be the train data to predict the stock price after 2014 using linear regression to check the accuracy.

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
# get the rows that contain the stock price in 2013 and 2014
train_index=[x for x in df.index if df.loc[x,"Date"].year==2013 or df.loc[x,"Date"].year==2014]

# create the sub dataframe that only contain the stock price of 2013 and 2014
df_train=df.loc[train_index]

# %% [markdown]
# I plan to use the value of open price, the highest price, and the lowest price to predict the close price. So, I create the train data to contain the columns of "Open", "High", and "Low".

# %%
# create the train data
X_train=df_train[["Open","High","Low"]]

# the true value of close price in 2013 and 2014
y_train=df_train["Close"]

# %%
# train the data
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
df_train["Pred"]=reg.predict(X_train)

# %% [markdown]
# Then, I plan to compare the precited close value for the year of 2015 and the true close value of 2015

# %%
# get the rows that contain the stock price in 2015
test_index=[x for x in df.index if df.loc[x,"Date"].year==2015]

# create the sub dataframe that only contain the stock price in 2015
df_test=df.loc[test_index]

# %%
X_test=df_test[["Open","High","Low"]]
y_test=df_test["Close"]

# %%
df_test["Pred"]=reg.predict(X_test)

# %%
# visualize the close price for 2015
c_true=alt.Chart(df_test).mark_line().encode(
    x="Date",
    y=alt.Y("Close", scale=alt.Scale(domain = [150,300])),
    tooltip=["Date","Close"]
)
c_true.properties(title = "Close Price for 2015")
# Out:
# alt.Chart(...)

# %%
# visualize the predicted close price for 2015
c_pred=alt.Chart(df_test).mark_line().encode(
    x="Date",
    y=alt.Y("Pred", scale=alt.Scale(domain = [150,300])),
    tooltip=["Date","Pred"],
    color=alt.value("#FFAA00"),
)
c_pred.properties(title = "Predicted Close Price for 2015")
# Out:
# alt.Chart(...)

# %%
df_test["difference"]=abs(df_test["Close"]-df_test["Open"])

# %% [markdown]
# In the end, I put the two graphs together to make a more direct comparision between the true price and predicted price.

# %%
c_together=c_true+c_pred

c_together=c_together.add_selection(
    interval
)

difference = alt.Chart(df_test).mark_line().encode(
    x="Date",
    y="difference"
).transform_filter(
    interval
)

c_together|difference
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# We can see from the chart that the true value of the close price and the predicted close is vary close since the two lines overlap each other a lot. Also, most of the difference is below 14, which is small compared the true close price, which value is between 150-200. But we will then use mean value error to evaluate the performance.

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df_test["Close"],df_test["Pred"])
# Out:
# 3.5567349637513797

# %%
mean_squared_error(df_train["Close"],df_train["Pred"])
# Out:
# 3.2347263243425592

# %% [markdown]
# The mean suqared error again shows that the well performance since the MSE for the train data is less than the MSE for the test data and they are very close.

# %% [markdown]
# ## Section3 K – Nearest Neighbor (KNN) Classification

# %% [markdown]
# In the section, I aim to use the difference between open price and high price, and the difference between open price and low price to classify stock into two categories: one is worth trading, which means the close price is higher than open price, and another is do not worth trade, which means the close price is lower than open price.

# %% [markdown]
# Similarly, I will use the data of 2013 and 2014 to predict the data of 2015

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# create the train data
X_train2=df_train[["Diff_high","Diff_low"]]

# the true value of close price in 2013 and 2014
y_train2=df_train["Worth"]

# %%
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)

classifier.fit(X_train2, y_train2)
# Out:
# KNeighborsClassifier()

# %%
# the test data contains the stock price in 2015
X_test2=df_test[["Diff_high","Diff_low"]]

y_test2=df_test["Worth"]

# %%
df_test.head()
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 1136 2015-01-02  222.869995  223.250000  213.259995  219.309998  4764400
# 1137 2015-01-05  214.550003  216.500000  207.160004  210.089996  5368500
# 1138 2015-01-06  210.059998  214.199997  204.210007  211.279999  6261900
# 1139 2015-01-07  213.350006  214.779999  209.779999  210.949997  2968400
# 1140 2015-01-08  212.809998  213.800003  210.009995  210.619995  3442500
#
#        Adj Close  Diff_high  Diff_low     Trade  Worth        Pred  difference
# 1136  219.309998   0.380005  9.610000 -3.559997      0  215.748410    3.559997
# 1137  210.089996   1.949997  7.389999 -4.460007      0  210.402004    4.460007
# 1138  211.279999   4.139999  5.849991  1.220001      1  208.881669    1.220001
# 1139  210.949997   1.429993  3.570007 -2.400009      0  211.647192    2.400009
# 1140  210.619995   0.990005  2.800003 -2.190003      0  211.323862    2.190003

# %%
df_test["Pred2"] = classifier.predict(X_test2)

# %% [markdown]
# In order to better visualize whether the stock is worth trading, I hightlight the value that is 1, which means worth trading.

# %%
df_test.style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_c373b_row2_col10,#T_c373b_row7_col10,#T_c373b_row8_col10,#T_c373b_row8_col13,#T_c373b_row10_col10,#T_c373b_row10_col13,#T_c373b_row12_col10,#T_c373b_row12_col13,#T_c373b_row13_col10,#T_c373b_row13_col13,#T_c373b_row14_col10,#T_c373b_row14_col13,#T_c373b_row15_col10,#T_c373b_row15_col13,#T_c373b_row16_col10,#T_c373b_row16_col13,#T_c373b_row18_col10,#T_c373b_row18_col13,#T_c373b_row19_col13,#T_c373b_row20_col10,#T_c373b_row20_col13,#T_c373b_row21_col10,#T_c373b_row21_col13,#T_c373b_row22_col10,#T_c373b_row22_col13,#T_c373b_row23_col10,#T_c373b_row23_col13,#T_c373b_row25_col10,#T_c373b_row25_col13,#T_c373b_row26_col13,#T_c373b_row27_col10,#T_c373b_row27_col13,#T_c373b_row28_col5,#T_c373b_row28_col10,#T_c373b_row28_col13,#T_c373b_row29_col10,#T_c373b_row29_col13,#T_c373b_row31_col10,#T_c373b_row32_col10,#T_c373b_row32_col13,#T_c373b_row33_col10,#T_c373b_row33_col13,#T_c373b_row37_col10,#T_c373b_row37_col13,#T_c373b_row40_col10,#T_c373b_row40_col13,#T_c373b_row41_col10,#T_c373b_row41_col13,#T_c373b_row45_col10,#T_c373b_row45_col13,#T_c373b_row46_col10,#T_c373b_row46_col13,#T_c373b_row48_col13,#T_c373b_row49_col10,#T_c373b_row50_col13,#T_c373b_row51_col10,#T_c373b_row51_col13,#T_c373b_row53_col10,#T_c373b_row54_col10,#T_c373b_row54_col13,#T_c373b_row55_col10,#T_c373b_row55_col13,#T_c373b_row59_col10,#T_c373b_row59_col13,#T_c373b_row62_col10,#T_c373b_row62_col13,#T_c373b_row63_col10,#T_c373b_row63_col13,#T_c373b_row64_col10,#T_c373b_row64_col13,#T_c373b_row65_col13,#T_c373b_row66_col10,#T_c373b_row67_col10,#T_c373b_row67_col13,#T_c373b_row68_col13,#T_c373b_row70_col10,#T_c373b_row70_col13,#T_c373b_row72_col10,#T_c373b_row74_col10,#T_c373b_row74_col13,#T_c373b_row75_col10,#T_c373b_row75_col13,#T_c373b_row76_col10,#T_c373b_row76_col13,#T_c373b_row78_col10,#T_c373b_row78_col13,#T_c373b_row80_col10,#T_c373b_row80_col13,#T_c373b_row83_col10,#T_c373b_row83_col13,#T_c373b_row86_col10,#T_c373b_row86_col13,#T_c373b_row87_col10,#T_c373b_row88_col10,#T_c373b_row88_col13,#T_c373b_row89_col10,#T_c373b_row89_col13,#T_c373b_row92_col10,#T_c373b_row92_col13,#T_c373b_row93_col10,#T_c373b_row93_col13,#T_c373b_row94_col13,#T_c373b_row96_col10,#T_c373b_row96_col13,#T_c373b_row97_col10,#T_c373b_row97_col13,#T_c373b_row98_col13,#T_c373b_row100_col10,#T_c373b_row100_col13,#T_c373b_row104_col10,#T_c373b_row104_col13,#T_c373b_row106_col10,#T_c373b_row106_col13,#T_c373b_row107_col10,#T_c373b_row107_col13,#T_c373b_row108_col10,#T_c373b_row108_col13,#T_c373b_row111_col10,#T_c373b_row111_col13,#T_c373b_row112_col10,#T_c373b_row113_col10,#T_c373b_row113_col13,#T_c373b_row114_col10,#T_c373b_row114_col13,#T_c373b_row116_col10,#T_c373b_row118_col10,#T_c373b_row118_col13,#T_c373b_row120_col10,#T_c373b_row120_col13,#T_c373b_row122_col10,#T_c373b_row122_col13,#T_c373b_row123_col10,#T_c373b_row123_col13,#T_c373b_row125_col1,#T_c373b_row126_col3,#T_c373b_row126_col10,#T_c373b_row126_col13,#T_c373b_row132_col10,#T_c373b_row132_col13,#T_c373b_row134_col10,#T_c373b_row134_col13,#T_c373b_row135_col10,#T_c373b_row136_col2,#T_c373b_row136_col4,#T_c373b_row136_col6,#T_c373b_row136_col10,#T_c373b_row136_col11,#T_c373b_row136_col13,#T_c373b_row137_col13,#T_c373b_row138_col10,#T_c373b_row138_col13,#T_c373b_row142_col10,#T_c373b_row142_col13,#T_c373b_row144_col10,#T_c373b_row144_col13,#T_c373b_row147_col10,#T_c373b_row147_col13,#T_c373b_row148_col10,#T_c373b_row148_col13,#T_c373b_row151_col10,#T_c373b_row151_col13,#T_c373b_row152_col10,#T_c373b_row153_col10,#T_c373b_row153_col13,#T_c373b_row154_col10,#T_c373b_row154_col13,#T_c373b_row157_col10,#T_c373b_row157_col13,#T_c373b_row160_col13,#T_c373b_row161_col7,#T_c373b_row161_col9,#T_c373b_row161_col10,#T_c373b_row161_col12,#T_c373b_row161_col13,#T_c373b_row164_col10,#T_c373b_row164_col13,#T_c373b_row165_col10,#T_c373b_row165_col13,#T_c373b_row166_col10,#T_c373b_row166_col13,#T_c373b_row167_col13,#T_c373b_row168_col10,#T_c373b_row170_col10,#T_c373b_row171_col10,#T_c373b_row171_col13,#T_c373b_row173_col10,#T_c373b_row173_col13,#T_c3 ...
#             background-color:  lightgreen;
#         }</style><table id="T_c373b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Open</th>        <th class="col_heading level0 col2" >High</th>        <th class="col_heading level0 col3" >Low</th>        <th class="col_heading level0 col4" >Close</th>        <th class="col_heading level0 col5" >Volume</th>        <th class="col_heading level0 col6" >Adj Close</th>        <th class="col_heading level0 col7" >Diff_high</th>        <th class="col_heading level0 col8" >Diff_low</th>        <th class="col_heading level0 col9" >Trade</th>        <th class="col_heading level0 col10" >Worth</th>        <th class="col_heading level0 col11" >Pred</th>        <th class="col_heading level0 col12" >difference</th>        <th class="col_heading level0 col13" >Pred2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c373b_level0_row0" class="row_heading level0 row0" >1136</th>
#                         <td id="T_c373b_row0_col0" class="data row0 col0" >2015-01-02 00:00:00</td>
#                         <td id="T_c373b_row0_col1" class="data row0 col1" >222.869995</td>
#                         <td id="T_c373b_row0_col2" class="data row0 col2" >223.250000</td>
#                         <td id="T_c373b_row0_col3" class="data row0 col3" >213.259995</td>
#                         <td id="T_c373b_row0_col4" class="data row0 col4" >219.309998</td>
#                         <td id="T_c373b_row0_col5" class="data row0 col5" >4764400</td>
#                         <td id="T_c373b_row0_col6" class="data row0 col6" >219.309998</td>
#                         <td id="T_c373b_row0_col7" class="data row0 col7" >0.380005</td>
#                         <td id="T_c373b_row0_col8" class="data row0 col8" >9.610000</td>
#                         <td id="T_c373b_row0_col9" class="data row0 col9" >-3.559997</td>
#                         <td id="T_c373b_row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_c373b_row0_col11" class="data row0 col11" >215.748410</td>
#                         <td id="T_c373b_row0_col12" class="data row0 col12" >3.559997</td>
#                         <td id="T_c373b_row0_col13" class="data row0 col13" >0</td>
#             </tr>
#             <tr>

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
ac = accuracy_score(y_test2,classifier.predict(X_test2))
ac
# Out:
# 0.8373015873015873

# %% [markdown]
# We can see from above that the accuracy is 0.837, which is high.

# %% [markdown]
# ## Summary

# %% [markdown]
# So, in the project, I use linear regression to predict the future close price for Tesla and find the prediction is very close to the true price. Also, I use K-Nearest Neighbor to classify the data into worthing trading, where the close price is higher than the open price and not worth trading, where the close price is lower than the open price. The K-Nearest Neighbor also has high accuracy. Therefore, we can see although the stock market is volatile, we can still use some methods from Python to figure out the trend and the relationships between different prices.

# %% [markdown]
# ## References

# %% [markdown]
# https://www.kaggle.com/datasets/rpaguirre/tesla-stock-price
# Tesla Stock Price Dataset

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/01/a-quick-introduction-to-k-nearest-neighbor-knn-classification-using-python/

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1104847b-64fc-4edd-bccf-2b2d72fbf101' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
